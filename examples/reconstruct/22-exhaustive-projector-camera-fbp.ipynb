# %% [markdown]
# # Advanced reference: using `CameraSystem.PROJECTOR_CAMERA` with `pf_dev`
#
# <div class="admonition important alert alert-block alert-warning">
#
# This is an advanced tutorial thus its documentation is scarce. If you're especially interested, feel free to reach out to us.
#
# </div>

# %%
import tal

data = tal.io.read_capture('data/tal/plane-exhaustive-16x16x16x16.hdf5')
tal.reconstruct.compensate_laser_cos_dsqr(data)

# %%
volume_xyz = tal.reconstruct.get_volume_project_rw(data, depths=[1.0,])

# %%
H_1_fbp = tal.reconstruct.fbp.solve(data, wl_mean=0.25, wl_sigma=0.25, volume_xyz=volume_xyz, camera_system=tal.enums.CameraSystem.DIRECT_LIGHT)
# Out:
# tal.reconstruct.filter_H: Using wavelengths from 0.1639m to 0.5244m
# tal.reconstruct.filter_H (pf, 3/3): 100%|██████████| 3/3 [00:03<00:00,  1.27s/it]
# tal.reconstruct.utils: Assuming that volume_xyz is X_Y_Z_3

# %%
tal.plot.amplitude_phase(H_1_fbp, title='Reconstruction')

# %%
with tal.resources(cpu_processes=2, downscale=2):
    H_1_fbp = tal.reconstruct.fbp.solve(data, wl_mean=0.25, wl_sigma=0.25, volume_xyz=volume_xyz, camera_system=tal.enums.CameraSystem.DIRECT_LIGHT)
# Out:
# tal.reconstruct.filter_H: Using wavelengths from 0.1639m to 0.5244m
# tal.resources: Using 2 CPU processes and downscale 2
# ...
# tal.resources progress: 100%|██████████| 2/2 [00:00<00:00, 54120.05it/s]
# tal.reconstruct.utils: Assuming that volume_xyz is X_Y_Z_3
# tal.resources: Using 2 CPU processes and downscale 2
# tal.resources progress: 100%|██████████| 2/2 [00:00<00:00, 36631.48it/s]

# %%
tal.plot.amplitude_phase(H_1_fbp, title='Multiple threads')

# %%
with tal.resources(cpu_processes=2, downscale=4):
    H_1_fbp = tal.reconstruct.fbp.solve(data, wl_mean=0.25, wl_sigma=0.25, volume_xyz=volume_xyz, camera_system=tal.enums.CameraSystem.DIRECT_LIGHT)
# Out:
# tal.reconstruct.filter_H (pf, 1/3):   0%|          | 0/3 [00:00<?, ?it/s]
# tal.reconstruct.filter_H: Using wavelengths from 0.1639m to 0.5244m
# tal.resources: Using 2 CPU processes and downscale 4
# ...
# tal.resources progress: 100%|██████████| 4/4 [00:00<00:00, 161319.38it/s]
# tal.reconstruct.utils: Assuming that volume_xyz is X_Y_Z_3
# tal.resources: Using 2 CPU processes and downscale 4
# tal.resources progress: 100%|██████████| 4/4 [00:00<00:00, 124275.67it/s]

# %%
tal.plot.amplitude_phase(H_1_fbp, title='Multiple threads')

# %%
with tal.resources(cpu_processes=2, downscale=2):
    H_1_fbp = tal.reconstruct.fbp.solve(data, wl_mean=0.25, wl_sigma=0.25, volume_xyz=volume_xyz,
                                        projector_focus=[0, -0.5, 1],
                                        camera_system=tal.enums.CameraSystem.PROJECTOR_CAMERA_T0)
# Out:
# tal.reconstruct.filter_H (pf, 1/3):   0%|          | 0/3 [00:00<?, ?it/s]
# tal.reconstruct.filter_H: Using wavelengths from 0.1639m to 0.5244m
# tal.resources: Using 2 CPU processes and downscale 2
# ...
# tal.resources progress: 100%|██████████| 2/2 [00:00<00:00, 103563.06it/s]
# tal.reconstruct.utils: Assuming that volume_xyz is X_Y_Z_3
# tal.resources: Using 2 CPU processes and downscale 2
# tal.resources progress: 100%|██████████| 2/2 [00:00<00:00, 65027.97it/s]

# %%
tal.plot.amplitude_phase(H_1_fbp, title='Focus illumination')

# %%
with tal.resources(cpu_processes=2, downscale=2):
    H_1_fbp = tal.reconstruct.fbp.solve(data, wl_mean=0.25, wl_sigma=0.25, volume_xyz=volume_xyz,
                                        projector_focus=[-0.5, 0, 1],
                                        camera_system=tal.enums.CameraSystem.PROJECTOR_CAMERA_T0)
# Out:
# tal.reconstruct.filter_H (pf, 1/3):   0%|          | 0/3 [00:00<?, ?it/s]
# tal.reconstruct.filter_H: Using wavelengths from 0.1639m to 0.5244m
# tal.resources: Using 2 CPU processes and downscale 2
# ...
# tal.resources progress: 100%|██████████| 2/2 [00:00<00:00, 103563.06it/s]
# tal.reconstruct.utils: Assuming that volume_xyz is X_Y_Z_3
# tal.resources: Using 2 CPU processes and downscale 2
# tal.resources progress: 100%|██████████| 2/2 [00:00<00:00, 67650.06it/s]

# %%
tal.plot.amplitude_phase(H_1_fbp, title='Focus illumination')

# %%
with tal.resources(cpu_processes=2, downscale=2):
    H_1_fbp = tal.reconstruct.fbp.solve(data, wl_mean=0.25, wl_sigma=0.25, volume_xyz=volume_xyz,
                                        projector_focus=[0, 0.5, 1],
                                        camera_system=tal.enums.CameraSystem.PROJECTOR_CAMERA_T0)
# Out:
# tal.reconstruct.filter_H (pf, 1/3):   0%|          | 0/3 [00:00<?, ?it/s]
# tal.reconstruct.filter_H: Using wavelengths from 0.1639m to 0.5244m
# tal.resources: Using 2 CPU processes and downscale 2
# ...
# tal.resources progress: 100%|██████████| 2/2 [00:00<00:00, 64527.75it/s]
# tal.reconstruct.utils: Assuming that volume_xyz is X_Y_Z_3
# tal.resources: Using 2 CPU processes and downscale 2
# tal.resources progress: 100%|██████████| 2/2 [00:00<00:00, 50231.19it/s]

# %%
tal.plot.amplitude_phase(H_1_fbp, title='Focus illumination')

# %%
with tal.resources(cpu_processes=2, downscale=2):
    H_1_fbp = tal.reconstruct.fbp.solve(data, wl_mean=0.25, wl_sigma=0.25, volume_xyz=volume_xyz,
                                        projector_focus=[0.5, 0, 1],
                                        camera_system=tal.enums.CameraSystem.PROJECTOR_CAMERA_T0)
# Out:
# tal.reconstruct.filter_H (pf, 1/3):   0%|          | 0/3 [00:00<?, ?it/s]
# tal.reconstruct.filter_H: Using wavelengths from 0.1639m to 0.5244m
# tal.resources: Using 2 CPU processes and downscale 2
# ...
# tal.resources progress: 100%|██████████| 2/2 [00:00<00:00, 66052.03it/s]
# tal.reconstruct.utils: Assuming that volume_xyz is X_Y_Z_3
# tal.resources: Using 2 CPU processes and downscale 2
# tal.resources progress: 100%|██████████| 2/2 [00:00<00:00, 69905.07it/s]

# %%
tal.plot.amplitude_phase(H_1_fbp, title='Focus illumination')

# %%
import tal

data = tal.io.read_capture('data/tal/plane-exhaustive-16x16x16x16.hdf5')

# %%
with tal.resources(cpu_processes=2, downscale=4):
    H_1_fbp = tal.reconstruct.fbp.solve(data, wl_mean=0.25, wl_sigma=0.25, volume_xyz=volume_xyz, camera_system=tal.enums.CameraSystem.DIRECT_LIGHT)
# Out:
# tal.reconstruct.filter_H: Using wavelengths from 0.1639m to 0.5244m
# tal.resources: Using 2 CPU processes and downscale 4
# ...
# tal.resources progress: 100%|██████████| 4/4 [00:00<00:00, 197379.01it/s]
# tal.reconstruct.utils: Assuming that volume_xyz is X_Y_Z_3
# tal.resources: Using 2 CPU processes and downscale 4
# tal.resources progress: 100%|██████████| 4/4 [00:00<00:00, 92691.80it/s]

# %%
tal.plot.amplitude_phase(H_1_fbp, title='Without compensating laser cos and d^2')

# %%
# Note that this reconstruction shows a brighter spot due to the position of the laser
print(data.laser_xyz)
# the image above goes from (-1, -1) in the top left corner to (1, 1) in the bottom right corner
# Out:
# [-0.5   0.    0.25]
